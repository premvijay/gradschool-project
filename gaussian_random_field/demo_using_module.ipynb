# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
from random_fields import GaussianRandomField

# %%
# grf1 = GaussianRandomField()
# def P(k):
#     return k
# grf1.Pk()

# %%
grf1 = GaussianRandomField()
grf1.set_Pk_power_law(1.0,1)

# %%
grf1.generate_from_Pk(shape=(128,128,128))
# grf1.FX[0,0,0] =0

# %%
grf1.visualise(title="2D slice of Gaussian random field with $P(k) \propto k$")    # Engine independent matplotlib based interaction
# Out:
# <img src="data:image/png;base64,..." width="768">

# %%
# Jupyter based interaction
from ipywidgets import interact
fig2, ax2 = plt.subplots(dpi=120)
im2 = ax2.imshow(grf1.FX[:,:,10])
cb2 = fig2.colorbar(im2,ax=ax2)
ax2.set_title("2D slice of Gaussian random field with $P(k) \propto k$")
plt.savefig("GRF-scale-invariant-spectrum.pdf",bbox_inches="tight")
# plt.savefig("GRF-power_-2.pdf",bbox_inches="tight")
@interact(third_direction=(0,127))
def show2D(third_direction):
    im2.set_data(grf1.FX[:,:,third_direction])
# Out:
# <img src="data:image/png;base64,..." width="768">
# interactive(children=(IntSlider(value=63, description='third_direction', max=127), Output()), _dom_classes=('w…

# %%
grf1.compute_Pk_from_field()

# %%
grf1.plot_original_and_computed_Pk(bins=np.logspace(0.3,2, 500))
# Out:
# <img src="data:image/png;base64,..." width="768">
