# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def powerlaw(b,n):
    """Returns a function which is a power law in one variable."""
    return lambda k : b*k**n

# %%
P = powerlaw(1,2)   # powerspectrum defined as a power law

# %%
shape = (128,128)
shape = (128,128,128)
K1 = np.array(np.meshgrid(*[np.fft.fftfreq(x) * x for x in shape[:-1]],np.fft.rfftfreq(shape[-1]) * shape[-1]))
#    print(*np.arange(len(shape),0,-1))
K = K1#.transpose(0,*np.arange(len(shape),0,-1))
# K = np.indices(shape,dtype='float')  # K vector
k = (K**2).sum(axis=0)**(1/2)    # magnitude of K vector
# k.shape
Pk = P(k)
Pk[0,0] = 0

# %%
K1.shape
# Out:
# (3, 128, 128, 65)

# %%
np.random.seed(840900)
FK = (np.random.randn(*k.shape) + np.random.randn(*k.shape)*1j) * np.sqrt(Pk/2)

# %%
plt.figure(dpi=120)
plt.imshow(np.real(FK[60]))
# plt.plot(Fx)

# %%
# from scipy.fftpack import fftn, ifftn

# %%
FX = np.fft.irfftn(FK)

# %%
plt.figure(dpi=120)
plt.imshow(FX[50])
# plt.plot(np.real(Fk*np.conj(Fk)))

# %%
F1K = np.fft.rfftn(FX)
# plt.plot(k.ravel(),np.abs(F1K.ravel())**2,'.')
F1K.shape
# Out:
# (128, 128, 65)

# %%
import pandas as pd

# %%
df = pd.DataFrame(data=np.vstack((k.ravel(),np.abs(F1K.ravel())**2)).T,columns=['k','Pk']).sort_values('k')
df
# Out:
#                   k            Pk
# 0          0.000000  2.019484e-28
# 8320       1.000000  6.183854e-01
# 8255       1.000000  1.065902e+00
# 1056640    1.000000  6.183854e-01
# 65         1.000000  1.065902e+00
# ...             ...           ...
# 536703   110.276924  7.731589e+03
# 536769   110.276924  5.971716e+02
# 545024   110.276924  4.605681e+03
# 528384   110.276924  4.605681e+03
# 536704   110.851252  1.157576e+03
#
# [1064960 rows x 2 columns]

# %%
k_av = df['k'].rolling(400).mean()
Pdata_av = df['Pk'].rolling(300).mean()
plt.figure(dpi=120)
plt.plot(k_av,Pdata_av, '-',label='Computed from the generated density field')
plt.plot(k_av,P(k_av),'-',label='Used to generate the density field')
plt.xscale('log')
plt.yscale('log')
plt.ylim(bottom=10)
plt.title("Power spectrum P(k)- simple avareging")
plt.legend(loc="lower right")

# %%
grouped1 = df.groupby('k').mean()
plt.figure(dpi=120)
plt.plot(grouped1.index,grouped1,'-',label='Computed from the generated density field')
plt.plot(grouped1.index,P(grouped1.index),'-',label='Used to generate the density field')
plt.xscale('log')
plt.yscale('log')
plt.ylim(bottom=1)
plt.title("Power spectrum P(k) - Averaged over directions but not averaged by bins")
plt.legend()

# %%
grouped2 = df.groupby(pd.cut(df['k'], bins=np.linspace(df['k'].iloc[0],df['k'].iloc[-1], 1000))).mean()
plt.figure(dpi=120)
plt.plot(grouped2['k'],grouped2['Pk'],'-',label='Computed from the generated density field')
plt.plot(grouped2['k'],P(grouped2['k']),'-',label='Used to generate the density field')
plt.xscale('log')
plt.yscale('log')
plt.ylim(bottom=10)
plt.title("Power spectrum P(k) - Averaged over linearly equispaced bins")
plt.legend()

# %%
plt.figure(dpi=120)
grouped3 = df.groupby(pd.cut(df['k'], bins=np.logspace(0.5,2, 600))).mean()
plt.plot(grouped3['k'],P(grouped3['k']),'-',label='Used to generate the density field')
plt.plot(grouped3['k'],grouped3['Pk'],'-',label='Computed from the generated density field')
plt.xscale('log')
plt.yscale('log')
plt.ylim(bottom=10)
plt.title("Power spectrum P(k) - Averaged over logarithmically spaced bins")
plt.legend(loc="upper left")

# %%
a = np.zeros((2, 3, 2))

a[0, 1, 0]= 3 * 2 * 2

np.fft.ifftn(a)
# Out:
# array([[[ 1. +0.j       ,  1. +0.j       ],
#         [-0.5+0.8660254j, -0.5+0.8660254j],
#         [-0.5-0.8660254j, -0.5-0.8660254j]],
#
#        [[ 1. +0.j       ,  1. +0.j       ],
#         [-0.5+0.8660254j, -0.5+0.8660254j],
#         [-0.5-0.8660254j, -0.5-0.8660254j]]])

# %%
np.fft.fftfreq(5)*5
# Out:
# array([ 0.,  1.,  2., -2., -1.])

# %%
# import sys, os
# sys.path

# %%
# import yt

# %%
# dir(yt)

# %%
# from scipy.ndimage import correlate

# %%
# corr = correlate(np.abs(FX),np.abs(FX),mode='nearest')

# %%
# corr.shape

# %%
# plt.imshow(corr)

# %%
# Pcor = fftn(corr)

# %%
# plt.imshow(np.abs(Pcor))

# %%
# np.abs(Pcor)

# %%
np.fft.fftfreq(10) * 10

# %%
128*128

# %%
# plot = plt.hist(np.real(F1K),bins=300)

# %%
# plt.hist(Fx,bins=30)

# %%
K[:,1,3,0]
